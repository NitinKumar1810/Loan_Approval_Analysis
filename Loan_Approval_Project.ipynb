# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset Loading

# %%
# lets import the dataset using the read_csv function

df = pd.read_csv('loan_sanction_test.csv')

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# # Shape of the Dataset

# %%
# lets check the shape of the dataset

df.shape
# Out:
# (367, 12)

# %% [markdown]
# # Viewing Columns

# %%
# lets check the column names present in the dataset

df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# # Dataset First View

# %%
# lets check the head of the dataset

df.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate           NaN
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# ...

# %% [markdown]
# # Drop Loan_id Column

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
df
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
# ...

# %% [markdown]
# # Description of the Data

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             356 non-null    object
#  1   Married            367 non-null    object
#  2   Dependents         357 non-null    object
#  3   Education          367 non-null    object
#  4   Self_Employed      344 non-null    object
#  5   ApplicantIncome    367 non-null    int64
#  6   CoapplicantIncome  367 non-null    int64
#  7   LoanAmount         362 non-null    float64
#  8   Loan_Amount_Term   361 non-null    float64
#  9   Credit_History     338 non-null    float64
#  10  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 31.7+ KB

# %% [markdown]
# # Finding Null Values in dataset

# %%
# checking no. of Missing values

df.isnull().sum()
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# Checking null value rows in Gender column

df[df.Gender.isnull()]
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 22     NaN      No          0      Graduate            No             3909
# 51     NaN     Yes         3+  Not Graduate            No             3500
# 106    NaN      No          0      Graduate            No             1596
# 138    NaN      No        NaN      Graduate            No             3333
# 209    NaN      No          1  Not Graduate            No             2038
# 231    NaN      No          0      Graduate           Yes             2860
# 245    NaN     Yes          0      Graduate            No             3186
# 279    NaN      No          0      Graduate            No            29167
# 296    NaN      No          0      Graduate            No             6478
# 303    NaN     Yes          1  Not Graduate           Yes              570
# 318    NaN      No          0  Not Graduate            No             4768
#
# ...

# %%
# Checking null value rows in Dependents column

df[df.Dependents.isnull()]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 46     Male     Yes        NaN  Not Graduate            No             4163
# 70   Female      No        NaN      Graduate            No             3250
# 111    Male     Yes        NaN      Graduate            No             4082
# 138     NaN      No        NaN      Graduate            No             3333
# 202    Male     Yes        NaN      Graduate            No             3016
# 247    Male     Yes        NaN      Graduate            No            10000
# 251    Male     Yes        NaN      Graduate            No             3863
# 265    Male      No        NaN      Graduate            No             3579
# 302  Female      No        NaN      Graduate           Yes            14987
# 312    Male      No        NaN      Graduate            No             2066
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
# Checking null value rows in Self_Employed column

df[df.Self_Employed.isnull()]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 8      Male     Yes          2      Graduate           NaN            13633
# 11     Male     Yes          1      Graduate           NaN             2185
# 13     Male     Yes          2      Graduate           NaN            12173
# 36     Male     Yes          2      Graduate           NaN             7350
# 72     Male     Yes          1      Graduate           NaN             4083
# 89   Female      No          0      Graduate           NaN             5058
# 142    Male     Yes         3+  Not Graduate           NaN             6794
# 161    Male      No          0      Graduate           NaN             2964
# 168  Female     Yes         3+      Graduate           NaN             1750
# 175    Male     Yes          2      Graduate           NaN             4912
# 192    Male     Yes          2  Not Graduate           NaN             3785
# ...

# %%
# Checking null value rows in LoanAmount column

df[df.LoanAmount.isnull()]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 78     Male     Yes          1      Graduate            No             3413
# 101  Female     Yes          0      Graduate            No             2262
# 188    Male     Yes          0  Not Graduate            No            13083
# 247    Male     Yes        NaN      Graduate            No            10000
# 289    Male     Yes          1      Graduate            No             8333
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 78                4053         NaN             360.0             1.0
# 101                  0         NaN             480.0             0.0
# 188                  0         NaN             360.0             1.0
# 247                  0         NaN             360.0             1.0
# 289               4000         NaN             360.0             1.0
#
#     Property_Area
# 78      Semiurban
# 101     Semiurban
# 188         Rural
# ...

# %%
# Checking null value rows in Loan_Amount_Term column

df[df.Loan_Amount_Term.isnull()]
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 45    Male     Yes          0      Graduate            No             4260
# 48    Male      No          0      Graduate            No             6792
# 117   Male     Yes          1      Graduate            No             1516
# 129   Male     Yes          1  Not Graduate            No             3321
# 184   Male     Yes         3+      Graduate            No            10166
# 214   Male     Yes          0  Not Graduate            No             3754
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 45                3900       185.0               NaN             NaN
# 48                3338       187.0               NaN             1.0
# 117               2900        80.0               NaN             0.0
# 129               2088        70.0               NaN             1.0
# 184                750       150.0               NaN             1.0
# ...

# %%
# Checking null value rows in Credit_History column

df[df.Credit_History.isnull()]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 3      Male     Yes          2      Graduate            No             2340
# 12     Male      No         3+      Graduate            No             4166
# 26     Male     Yes          2      Graduate            No             4363
# 28     Male     Yes          0      Graduate            No             3772
# 45     Male     Yes          0      Graduate            No             4260
# 90     Male     Yes          0      Graduate           Yes             3188
# 99     Male     Yes         3+      Graduate            No             6835
# 104    Male      No          0      Graduate            No             2243
# 115    Male      No         3+      Graduate            No             4243
# 139  Female      No         3+      Graduate            No             4083
# 143    Male     Yes          0      Graduate           Yes            32000
# ...

# %% [markdown]
# # Handling Null Values

# %%
# Filling null values in Gender column

df.Gender = df.Gender.fillna(df.Gender.mode()[0])

# %%
# Filling null values in Dependents column

df.Dependents = df.Dependents.fillna(df.Dependents.mode()[0])

# %%
# Filling null values in Self_Employed column

df.Self_Employed = df.Self_Employed.fillna(df.Self_Employed.mode()[0])

# %%
# Filling null values in LoanAmount column

df.LoanAmount = df.LoanAmount.fillna(df.LoanAmount.median())

# %%
# Filling null values in Loan_Amount_Term column

df.Loan_Amount_Term = df.Loan_Amount_Term.fillna(df.Loan_Amount_Term.median())

# %%
# Filling null values in Credit_History column

df.Credit_History = df.Credit_History.fillna(df.Credit_History.mode()[0])

# %%
# lets check if there is any null values left or not

df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %% [markdown]
# ## Checking Outliers

# %%
sns.boxplot(x=df.ApplicantIncome)
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %% [markdown]
# # Observation:
# * The majority of the outliers are indentified, and they all exceeds 20000.

# %%
df[df.ApplicantIncome>20000]
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 81    Male     Yes         3+  Graduate            No            72529
# 143   Male     Yes          0  Graduate           Yes            32000
# 272   Male      No          1  Graduate            No            24797
# 279   Male      No          0  Graduate            No            29167
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 81                   0       360.0             360.0             1.0
# 143                  0       550.0             360.0             1.0
# 272                  0       240.0             360.0             1.0
# 279                  0       185.0             360.0             1.0
#
#     Property_Area
# 81          Urban
# 143     Semiurban
# 272     Semiurban
# 279     Semiurban

# %% [markdown]
# # Observation:
# * After analyzing the 'ApplicantIncome' column, an outlier was identified with a substantially high value of 72529. This exception is causing a deviation from the straight pattern in the chart, a decision was made to treat this specific entry as an outlier.
# * To mitigate the influence of the outlier, we replace this outlier with the upper limit. This adjustment is intended to align the corrected value more closely with the typical range of applicant incomes, facilitating a more accurate representation of the data for subsequent analyses.

# %%
# Find Q1 and Q3
Q1 = df.ApplicantIncome.quantile(.25)
Q3 = df.ApplicantIncome.quantile(.75)

# %%
Q1,Q3
# Out:
# (2864.0, 5060.0)

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 2196.0

# %%
# Finding Upper limit and Lower limit
UL = Q3+1.5*(IQR)
LL = Q1-1.5*(IQR)

# %%
UL,LL
# Out:
# (8354.0, -430.0)

# %%
# Replacing the outliers with UL
df.ApplicantIncome = np.where(df.ApplicantIncome==72529,UL,df.ApplicantIncome)

# %% [markdown]
# # Distribution of Loan Amount

# %%
sns.histplot(df['LoanAmount'], kde=True,color='Green')
plt.title('Distribution of Loan Amounts')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Observation:
# * The distribution of Loan Amount is right-skewed, indicating that there are a few applicants with significantly higher loan amounts. This suggests that there might be some outliers or a concentration of applicants seeking larger loan amounts.

# %% [markdown]
# # Distribution of Gender

# %%
sns.countplot(x='Gender', data=df, palette='flare')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The visualization reveals the distribution of genders among the loan applicants. It appears that there is a noticeable imbalance between male and female applicants. This could be due to various socio-economic factors influencing the willingness of individuals to apply for loans.

# %% [markdown]
# # Distribution of Education

# %%
sns.countplot(x='Education', data=df, palette='mako')
plt.title('Distribution of Education')
plt.xlabel('Education Level')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The data suggests that a larger proportion of loan applicants are graduates compared to those who are not graduates. This could be influenced by various factors, including the correlation between education and financial stability.
# * Financial institutions may consider the educational background of applicants is one of the factors affecting loan approval. Graduates may be perceived as having a higher income potential, which could influence lending decisions.
# * The education distribution among loan applicants enables the business to make informed decisions, provide targeted services, and foster financial literacy among its customer base.

# %% [markdown]
# # Distribution of Applicant Income

# %%
sns.histplot(df['ApplicantIncome'], kde=True,color='Green')
plt.title('Distribution of Applicant Income')
plt.xlabel('Applicant Income')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Observation:
# * The histogram shows that the distribution of Applicant Income is right-skewed, indicating that there are a few applicants with significantly higher incomes. This suggests income inequality or a concentration of higher-income applicants.
# * The right-skewed nature of the distribution highlights the income disparity among applicants. This could have implications for loan approval, as higher incomes might increase the ability to repay loans.

# %% [markdown]
# # Distribution of Marital Status

# %%
sns.countplot(x='Married', data=df , palette = 'cubehelix')
plt.title('Distribution of Marital Status')
plt.xlabel('Married')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The count plot visualizes the distribution of applicants based on their marital status, with categories such as 'Married' and 'Not Married'
# * There is a noticeable imbalance in the distribution, there are more married applicants compared to unmarried ones. It could reflect societal trends or demographic characteristics of the dataset.

# %% [markdown]
# # Distribution of Property Area

# %%
sns.countplot(x='Property_Area', data=df , palette='dark:salmon_r')
plt.title('Distribution of Property Area')
plt.xlabel('Property Area')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The count plot illustrates the distribution of applicants based on their property area. Common categories could include 'Urban', 'Semiurban', and 'Rural'.
# * There is a higher count in the 'Urban' category, it suggests a higher concentration of applicants from urban areas. This may be due to economic opportunities, better infrastructure, or other factors attracting applicants to urban locations.
# * Property area can influence loan products. For instance, loan products for rural areas might have different features or terms compared to those designed for urban or semiurban areas.

# %% [markdown]
# # Distribution of Dependents

# %%
sns.countplot(x='Dependents', data=df , palette='magma')
plt.title('Distribution of Dependents')
plt.xlabel('Number of Dependents')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The count plot illustrates the distribution of applicants based on the number of dependents. Categories may include '0', '1', '2', '3+', representing the number of dependents.
# * The number of dependents is often associated with financial responsibilities. Applicants with more dependents may have different financial needs and considerations compared to those with fewer or no dependents.
# * There are trends related to family sizes. For example, a higher count in '0' dependents indicate a significant presence of single applicants.

# %% [markdown]
# # Distribution of Credit History

# %%
sns.countplot(x='Credit_History', data=df, palette='icefire' )
plt.title('Distribution of Credit History')
plt.xlabel('Credit History')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The count plot illustrates the distribution of applicants based on their credit history. Categories may include '1(indicating a credit history exists) and '0' (indicating no credit history).
# * A higher count in the '1' category suggests a larger number of creditworthy applicants with a positive credit history.
# * The distribution provides insights into the prevalence of applicants with and without a credit history. Applicants with no credit history may pose a different risk profile, and this should be considered during the risk assessment process.
# * Credit history is a critical factor in loan approval. Understanding the distribution helps assess the proportion of applicants with a solid credit history, influencing approval rates.

# %% [markdown]
# # Distribution of Self Employed

# %%
sns.countplot(x='Self_Employed', data=df, palette='crest')
plt.title('Distribution of Self Employed')
plt.xlabel('Self Employed')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Observation:
# * The count plot illustrates the distribution of applicants based on their self-employment status. Categories may include 'Yes' (indicating self-employed) and 'No' (indicating not self-employed).
# * There is a significant count in the 'Yes' category, it indicates a notable presence of self-employed individuals or entrepreneurs among the loan applicants.
# * Self-employed individuals may have variable income structures compared to salaried individuals. Understanding their distribution provides insights into the diversity of income sources among loan applicants.

# %% [markdown]
# # Relationship between Applicant Income and Loan Amount

# %%
sns.scatterplot(x=df.ApplicantIncome,y=df.LoanAmount)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %% [markdown]
# # Observation:
# * There is a positive correlation between applicant income and loan amount. This means that as the applicant's income increases, they may be eligible for larger loan amounts.
# * Applicants with higher incomes may qualify for larger loans because they have the financial capacity to repay them.

# %% [markdown]
# ## Loan Amount Distribution by Property Area

# %%
property_loan_distribution = df.groupby('Property_Area')['LoanAmount'].sum()

# %%
property_loan_distribution
# Out:
# Property_Area
# Rural        15325.0
# Semiurban    15531.0
# Urban        19049.0
# Name: LoanAmount, dtype: float64

# %%
sns.barplot(x=property_loan_distribution.index,y=property_loan_distribution,palette='viridis')
plt.title('Loan Amount Distribution by Property Area')
plt.xlabel('Property_Area')
plt.ylabel('Total Loan Amount')
# Out:
# Text(0, 0.5, 'Total Loan Amount')

# %% [markdown]
# ## Observation:
# * Urban areas showcase higher loan amounts due to increased economic opportunities and property investments, while rural areas exhibit lower loan amounts due to less economic development.

# %% [markdown]
# ## Pairplot of numeric columns

# %%
sns.pairplot(df)
